# %% [markdown]
# # Data pre-processing before inputting to JASP to get nice plots

# %% [markdown]
# ## Load data

# %%
import pandas as pd

data = pd.read_csv("data.csv")
data = data.drop('Unnamed: 0', axis=1)
data
# Out:
#     age  gender country english attention_check d0_condition d1_condition  \
# 0    25    male      IT     med       [0, 1, 5]   model1_int   model2_int
# 1    24  female      GR     med       [0, 1, 5]   model0_ext   model0_ext
# 2    31  female      IT     med       [0, 1, 5]   model0_int   model2_ext
# 3    18  female      IT     med       [0, 1, 5]   model2_int   model1_ext
# 4    30    male      FI     med       [0, 1, 5]   model1_ext   model1_int
# 5    23  female      ZA    high       [0, 1, 5]   model2_ext   model0_int
# 6    63  female      GR     med          [0, 5]   model1_int   model2_int
# 7    26    male      GR     med       [0, 1, 5]   model0_ext   model0_ext
# 8    33  female      PL     med          [0, 1]   model0_int   model2_ext
# 9    36  female      ZA    high             [5]   model2_int   model1_ext
# 10   27    male      ZA     med          [0, 2]   model1_ext   model1_int
# 11   19  female      CA    high       [0, 1, 5]   model2_ext   model0_int
# 12   20    male      PL     med       [0, 1, 5]   model0_ext   model0_ext
# 13   21  female      MX     med       [0, 1, 5]   model0_int   model2_ext
# 14   20  female      SI     med       [0, 1, 5]   model2_int   model1_ext
# 15   20  female      PL     med       [0, 1, 5]   model1_ext   model1_int
# 16   19    male      SE     med             [0]   model1_int   model2_int
# 17   26    male      EE     med       [0, 1, 5]   model0_ext   model0_ext
# 18   19    male      PT     med             [1]   model0_int   model2_ext
# 19   25    male      MX     med       [0, 1, 5]   model2_int   model1_ext
# 20   26    male      HU     med       [0, 1, 2]   model1_ext   model1_int
# 21   25    male      PL     med       [0, 1, 5]   model2_ext   model0_int
# 22   29    male      GR    high       [0, 1, 5]   model1_int   model2_int
# 23   21  female      MX     med       [0, 1, 5]   model0_ext   model0_ext
# 24   27    male      MX     med       [0, 1, 2]   model2_int   model1_ext
# 25   22    male      PL     med       [0, 1, 5]   model1_ext   model1_int
# 26   30  female      PT    high       [0, 1, 5]   model2_ext   model0_int
# 27   22  female      ES     med       [0, 1, 2]   model1_int   model2_int
# 28   31  female      MX     med             [0]   model0_ext   model0_ext
#
#    d2_condition  d0_q1  d0_q2  ...  d2_q5  d2_q6  d2_q7  d2_q8  d2_q9  d2_q10  \
# 0    model2_ext      1      1  ...      5      2      1      2      3       4
# 1    model0_int      0      0  ...      3      2      3      3      4       2
# 2    model1_int      2      2  ...      1      4      5      4      3       4
# 3    model2_int      4      4  ...      4      1      2      1      1       1
# 4    model1_ext      0      5  ...      0      1      4      1      3       4
# 5    model0_ext      0      2  ...      0      6      6      6      6       6
# 6    model2_ext      0      3  ...      3      4      3      3      2       5
# 7    model0_int      3      4  ...      4      3      3      2      2       3
# 8    model1_int      1      3  ...      1      4      4      2      3       3
# 9    model2_int      4      5  ...      3      4      2      2      2       2
# 10   model1_ext      3      4  ...      6      6      5      4      5       5
# 11   model0_ext      2      1  ...      2      4      4      4      4       4
# 12   model0_int      1      3  ...      4      4      5      3      3       2
# 13   model1_int      4      5  ...      4      4      5      4      4       5
# 14   model2_int      2      1  ...      2      4      5      4      4       5
# 15   model1_ext      0      2  ...      1      3      3      4      2       4
# 16   model2_ext      1      1  ...      2      2      2      1      2       2
# 17   model0_int      1      3  ...      4      2      3      1      2       2
# 18   model1_int      3      3  ...      4      4      4      5      3       3
# 19   model2_int      3      3  ...      3      2      3      3      2       2
# 20   model1_ext      0      1  ...      1      4      4      4      4       5
# 21   model0_ext      1      1  ...      1      4      5      5      5       5
# 22   model2_ext      1      2  ...      2      3      3      3      3       3
# 23   model0_int      0      2  ...      1      4      6      3      3       6
# 24   model2_int      1      1  ...      1      4      5      4      2       4
# 25   model1_ext      1      3  ...      3      3      4      4      3       4
# 26   model0_ext      1      1  ...      1      3      5      4      4       4
# 27   model2_ext      2      2  ...      4      2      2      1      1       2
# 28   model0_int      4      0  ...      3      4      3      5      5       5
#
#     d2_q11  d2_q12  d2_q13  d2_q14
# 0        2       1       3       0
# 1        6       6       6       0
# 2        6       5       5       0
# 3        5       5       4       0
# 4        5       5       5       0
# 5        6       6       6       0
# 6        5       5       3       0
# 7        5       4       4       0
# 8        5       4       5       0
# 9        6       0       4       5
# 10       4       4       4       0
# 11       4       4       4       0
# 12       4       3       3       0
# 13       4       2       4       0
# 14       6       5       6       0
# 15       6       6       6       0
# 16       5       3       5       0
# 17       4       4       5       0
# 18       6       5       6       0
# 19       5       4       4       0
# 20       5       4       2       0
# 21       5       4       5       0
# 22       3       0       0       0
# 23       4       6       4       0
# 24       2       2       2       0
# 25       4       3       3       0
# 26       6       5       6       0
# 27       3       1       3       0
# 28       5       2       4       0
#
# [29 rows x 50 columns]

# %% [markdown]
# ## Remove failed attention checks

# %%
data = data[data['d0_q14'] == 0]
data = data[data['d1_q14'] == 0]
data = data[data['d2_q14'] == 0]
data['attention_check'][0]
to_drop = []
list(map(int, data['attention_check'][0][1:-1].split(',')))
for index, row in data.iterrows():
    a_c = list(map(int, row['attention_check'][1:-1].split(',')))
    if 0 in a_c and 1 in a_c:
        continue
    to_drop.append(index)
print(f'Dropped {len(to_drop)} rows')
data = data.drop(to_drop, axis=0)
# Out:
# Dropped 5 rows

# %% [markdown]
# ## Data 2 JASP

# %%
model2name = {'model0': 'Expert', 'model1': 'GPT-3', 'model2': 'STRAP'}
condition2personality = {'ext': 'Ext', 'int': 'Int'}
questions = [f'q{i+1}' for i in range(14)]
data2jasp = pd.DataFrame()
for _, row in data.iterrows():
    essential = {'Gender': row['gender'], 'Age': row['age'], 'Country': row['country'], 'English': row['english']}
    for dialogue in [f'd{i}' for i in range(3)]:
        essential['Dialogue'] = int(dialogue[-1]) + 1
        essential['Condition'] = dialogue + "_" + row[f'{dialogue}_condition']
        essential['Model'] = model2name[row[f'{dialogue}_condition'][:6]]
        essential['Personality'] = condition2personality[row[f'{dialogue}_condition'][-3:]]
        essential['Introversion rating'] = row[[f'{dialogue}_q{i+1}' for i in range(5)]].mean()
        essential['Extraversion rating'] = row[[f'{dialogue}_q{i+6}' for i in range(5)]].mean()
        essential['Extraversion'] = (essential['Extraversion rating'] + 6 - essential['Introversion rating']) / 2
        essential['Fluency rating'] = row[[f'{dialogue}_q{i+11}' for i in range(3)]].mean()
        data2jasp = data2jasp.append(essential, ignore_index=True)
overall = []
for i, row in data2jasp.iterrows():
    score = row['Extraversion rating'] - row['Introversion rating']
    if row['Personality'] == 'Int':
        score *= -1
    score += 6
    score /= 2
    overall.append(score)
data2jasp['Personality overall'] = overall
data2jasp.to_csv("data2jasp.csv", index=False)
data2jasp
# Out:
#     Gender   Age Country English  Dialogue      Condition   Model Personality  \
# 0     male  25.0      IT     med       1.0  d0_model1_int   GPT-3         Int
# 1     male  25.0      IT     med       2.0  d1_model2_int   STRAP         Int
# 2     male  25.0      IT     med       3.0  d2_model2_ext   STRAP         Ext
# 3   female  24.0      GR     med       1.0  d0_model0_ext  Expert         Ext
# 4   female  24.0      GR     med       2.0  d1_model0_ext  Expert         Ext
# ..     ...   ...     ...     ...       ...            ...     ...         ...
# 64  female  30.0      PT    high       2.0  d1_model0_int  Expert         Int
# 65  female  30.0      PT    high       3.0  d2_model0_ext  Expert         Ext
# 66  female  22.0      ES     med       1.0  d0_model1_int   GPT-3         Int
# 67  female  22.0      ES     med       2.0  d1_model2_int   STRAP         Int
# 68  female  22.0      ES     med       3.0  d2_model2_ext   STRAP         Ext
#
#     Introversion rating  Extraversion rating  Extraversion  Fluency rating  \
# 0                   1.0                  4.8           4.9        4.333333
# 1                   1.8                  4.6           4.4        3.333333
# 2                   4.2                  2.4           2.1        2.000000
# 3                   0.4                  5.8           5.7        6.000000
# 4                   0.4                  6.0           5.8        6.000000
# ..                  ...                  ...           ...             ...
# 64                  3.4                  1.8           2.2        3.666667
# 65                  1.6                  4.0           4.2        5.666667
# 66                  2.2                  4.6           4.2        6.000000
# 67                  2.0                  4.2           4.1        3.333333
# 68                  4.0                  1.6           1.8        2.333333
#
#     Personality overall
# 0                   1.1
# 1                   1.6
# 2                   2.1
# 3                   5.7
# 4                   5.8
# ..                  ...
# 64                  3.8
# 65                  4.2
# 66                  1.8
# 67                  1.9
# 68                  1.8
#
# [69 rows x 13 columns]
